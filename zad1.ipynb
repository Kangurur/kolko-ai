# %% [markdown]
# ## Napisz pętlę, która wyświetli parzyste liczby od 1 do 100

# %% [markdown]
# ## Napisz funkcję, która wyświetli elementy podanej tablicy podniesione do kwadratu

# %%
def f(tab: list) -> None:
    pass

# %% [markdown]
# test

# %%
f([1,2,3])
f([2,1,3,7])
f(list(range(100,49,-1)))

# %% [markdown]
# ## Napisz funkcję, która przyjmuje dwa stringi i zwraca 'zmiksowanego' stringa
# np dla "abc" i "123" zwraca "a1b2c3"
#
# możesz założyć, że stringi są równej długości

# %%
def mix(s1:str, s2:str) -> str:
    pass

# %% [markdown]
# test

# %%
print(mix("abc","123"))
print(mix("string1","string2"))
print(mix("x"*10,"jeleń"*2))

# %% [markdown]
# ## Naklep binsearcha (niech zwraca indeks szukanego elementu)
#
# Możesz założyć, że podana tablica jest posortowana

# %%
def binsearch(tab:list, x:int) -> int:
    pass

# %% [markdown]
# test

# %%
print(binsearch([1,2,3],3))
print(binsearch(sorted([2,1,3,7]),1))
print(binsearch(list(range(10,100)),40))
